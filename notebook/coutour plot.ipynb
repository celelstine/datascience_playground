# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
# snippet below would set the circumference of the figure and pixel density
# width_of_panel = 4
# height_of_panel = 3
# d = 1000
# plt.figure(figsize=(width_of_panel, height_of_panel), dpi=d)

x = np.arange(0, 25, 1)
y = np.arange(0, 25, 1)

# the mash grid function would help create a reectangle grid such that each point has a value of x and y
x, y = np.meshgrid(x, y)
plt.plot(x,y, marker='.', color='k', linestyle='none')
plt.show()

z = np.sin(x/3) + np.cos(y/4)#np.sin(x * np.pi / 2) + np.cos(y * np.pi / 3)

plt.contour(x, y, z)
